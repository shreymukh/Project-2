# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup
import requests
import urllib.parse
import pymongo
import pprint
import pandas as pd

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.stocks
collection = db.small_cap

# %%
url = 'https://www.barchart.com/stocks/most-active/price-volume-leaders?screener=small_cap'
response = requests.get(url)
print(response.status_code)
# Out:
# 403

# %%
# searchterm = urllib.parse.quote('left bold plusIconTd elp')
# print(searchterm)

# %%
# SCRAPING 
# Set the executable path and initialize the chrome browser in splinter
executable_path = {"executable_path":"chromedriver.exe"}
browser = Browser("chrome", **executable_path, headless=False)
browser.visit("https://www.barchart.com/stocks/most-active/price-volume-leaders?screener=small_cap")

# %%
# Convert the browser html to a soup object 
soup = browser.html
stock_soup = BeautifulSoup(soup, 'html.parser')

# %%
#print(stock_soup.prettify())

# %%
stock_symbol = stock_soup.find("td", class_= "symbol text-left").text
print(stock_symbol)
# Out:
#          PLUG

# %%
stock_name = stock_soup.find("td", class_= "symbolName text-left").text
print(stock_name)
# Out:
#        Plug Power Inc

# %%
stock_price = stock_soup.find("td", class_= "lastPrice").text
print(stock_price)
# Out:
#        3.76

# %%
stock_volume = stock_soup.find("td", class_= "volume").text
print(stock_volume)
# Out:
#        25,289,817

# %%
stock_change = stock_soup.find("td", class_= "percentChange up").text
print(stock_change)
# Out:
#        +16.41%

# %%
stock_symbol_all = stock_soup.find_all("td", class_= "symbol text-left")
stock_name_all = stock_soup.find_all("td", class_= "symbolName text-left")
stock_price_all = stock_soup.find_all("td", class_= "lastPrice")
stock_volume_all = stock_soup.find_all("td", class_= "volume")
stock_change_all = stock_soup.find_all("td", class_= "percentChange up")

# print(stock_symbol_all)

# print(stock_name_all)

# print(stock_price_all)

# print(stock_volume_all)

# print(stock_change_all)

# %%
symbol =[]
for stock in stock_symbol_all:
    #print(stock.text)
    symbol_list = symbol.append(stock.text)
    #print(symbol)

# %%
price =[]
for stock in stock_price_all:
    #print(stock.text)
    price_list = price.append(stock.text)
    #print(price)

# %%
volume = []   
for vol in stock_volume_all:
    #print(vol.text)
    volume_list = volume.append(vol.text)
    #print(volume)

# %%
name = []   
for names in stock_name_all:
    #print(names.text)
    names_list = name.append(names.text)
    #print(name)

# %%
change = []   
for names in stock_change_all:
    #print(names.text)
    change_list = change.append(names.text)
    #print(change)

# %%
# Convert to Pandas dataframe and export in csv
df = pd.DataFrame({'stock_name':name, 'stock_symbol':symbol,'stock_price':price, 'stock_volume':volume}) 
df
# Out:
#                                            stock_name        stock_symbol  \
# 0                                Plug Power Inc                 PLUG
# 1                                 Rite Aid Corp                  RAD
# 2                  Nebula Acquisition Corp Cl A                 NEBU
# 3                           Fuelcell Energy Inc                 FCEL
# 4                                    Habit Rest                 HABT
# 5                        Whiting Petroleum Corp                  WLL
# 6                     California Resources Corp                  CRC
# 7                           Signet Jewelers Ltd                  SIG
# 8                          Children's Place Inc                 PLCE
# 9                             Overstock.com Inc                 OSTK
# 10                                 Inseego Corp                 INSG
# 11             Innovative Industrial Properties                 IIPR
# 12                          Clovis Oncology Inc                 CLVS
# 13               Jinkosolar Holding Company Ltd                  JKS
# 14                Laredo Petroleum Holdings Inc                  LPI
# 15                                  Telaria Inc                 TLRA
# 16                           Everquote Inc Cl A                 EVER
# 17                                  Dermira Inc                 DERM
# 18                                Tivity Health                 TVTY
# 19                      The Rubicon Project Inc                 RUBI
# 20                          Vericel Corproation                 VCEL
# 21                          Pacific Biosciences                 PACB
# 22                        Antero Resources Corp                   AR
# 23                 Virgin Galactic Holdings Inc                 SPCE
# 24                         Fortuna Silver Mines                  FSM
# 25               Amc Entertainment Holdings Inc                  AMC
# 26                               Funko Inc Cl A                 FNKO
# 27                        Pacific Drilling S.A.                 PACD
# 28                                  Cerence Inc                 CRNC
# 29                       Eros International Plc                 EROS
# ..                                                ...                 ...
# 71                              Lannett Co. Inc                  LCI
# 72          Axonics Modulation Technologies Inc                 AXNX
# 73                           Tenneco Automotive                  TEN
# 74                            Intersect Ent Inc                 XENT
# 75                            Apogee Entrpr Inc                 APOG
# 76            GS Acquisition Holdings Corp Cl A                 GSAH
# 77                              Digital Turbine                 APPS
# 78                                Intrexon Corp                  XON
# 79                         Northern Oil and Gas                  NOG
# 80                        Endeavour Silver Corp                  EXK
# 81                                     Gogo Inc                 GOGO
# 82                         Ultra Clean Holdings                 UCTT
# 83                  Evolent Health Inc Cl A Com                  EVH
# 84                              MAG Silver Corp                  MAG
# 85                                 Cars.com Inc                 CARS
# 86                          Upland Software Inc                 UPLD
# 87                  Kiniksa Pharmaceuticals Ltd                 KNSA
# 88                       Briggs & Stratton Corp                  BGG
# 89                     Bioxcel Therapeutics Inc                 BTAI
# 90                              Nanostring Tech                 NSTG
# 91                                  Durect Corp                 DRRX
# 92                            Dynamic Materials                 BOOM
# 93                     Bonanza Creek Energy Inc                 BCEI
# 94            Foundation Building Materials Inc                  FBM
# 95                                   Mechel Oao                  MTL
# 96                                Domo Inc Cl B                 DOMO
# 97                             Acco Brands Corp                 ACCO
# 98                                   Nv5 Global                 NVEE
# 99                                 Viking Thera                 VKTX
# 100                                            Name              Symbol
#
#             stock_price             stock_volume
# 0            3.76               25,289,817
# 1           13.37                5,911,948
# 2           10.57                6,573,937
# 3            2.25               26,288,284
# 4           13.93                4,119,986
# 5            7.96                6,077,992
# 6           10.42                3,613,653
# 7           18.48                1,368,640
# 8           63.75                  389,933
# 9            7.85                2,985,938
# 10           7.95                2,456,808
# 11          77.54                  240,438
# 12           9.41                1,846,967
# 13          22.35                  742,732
# 14           2.99                5,402,810
# 15          10.39                1,486,078
# 16          29.49                  512,647
# 17          14.52                1,054,318
# 18          21.14                  710,878
# 19           9.64                1,517,134
# 20          17.38                  808,747
# 21           5.11                2,757,187
# 22           2.56                5,354,985
# 23          11.49                1,138,065
# 24           4.11                2,976,065
# 25           7.18                1,682,660
# 26          16.64                  717,898
# 27           6.04                1,946,118
# 28          22.21                  533,058
# 29           3.72                3,223,247
# ..                  ...                      ...
# 71           8.04                  748,243
# 72          27.06                  219,684
# 73          13.58                  431,067
# 74          24.76                  234,633
# 75          32.66                  177,701
# 76          11.23                  508,540
# 77           7.42                  767,086
# 78           6.05                  927,156
# 79           2.27                2,492,002
# 80           2.36                2,358,594
# 81           6.20                  893,207
# 82          21.95                  250,522
# 83           9.07                  591,300
# 84          11.37                  468,045
# 85          11.78                  450,466
# 86          38.99                  135,808
# 87          12.71                  410,617
# 88           6.04                  853,207
# 89          16.00                  320,430
# 90          26.99                  188,649
# 91           2.83                1,794,945
# 92          45.91                  109,025
# 93          25.09                  198,914
# 94          19.22                  257,734
# 95           2.69                1,826,111
# 96          22.55                  221,789
# 97           9.16                  532,699
# 98          53.21                   90,501
# 99           7.61                  630,162
# 100              Last                   Volume
#
# [101 rows x 4 columns]

# %%
# Importing the dataframe into mongodb

data = df.to_dict(orient='records')  # Here's our added param..

collection.insert_many(data)

# %%
# >>> collection.insert_many(df.to_dict('records')) # you need to pass the 'records' as argument in order to get a list of dict.

# %%
df.to_csv('stocks_mid_cap.csv', index=False, encoding='utf-8')
