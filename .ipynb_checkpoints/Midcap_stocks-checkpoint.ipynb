# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup
import requests
import urllib.parse
import pymongo
import pprint
import pandas as pd

# %%
url = 'https://www.barchart.com/stocks/most-active/price-volume-leaders?screener=large_cap&viewName=main&orderBy=volume&orderDir=desc'
response = requests.get(url)
print(response.status_code)
# Out:
# 403

# %%
# searchterm = urllib.parse.quote('left bold plusIconTd elp')
# print(searchterm)

# %%
# SCRAPING 
# Set the executable path and initialize the chrome browser in splinter
executable_path = {"executable_path":"chromedriver.exe"}
browser = Browser("chrome", **executable_path, headless=False)
browser.visit("https://www.barchart.com/stocks/most-active/price-volume-leaders?screener=large_cap&viewName=main&orderBy=volume&orderDir=desc")

# %%
# Convert the browser html to a soup object 
soup = browser.html
stock_soup = BeautifulSoup(soup, 'html.parser')

# %%
#print(stock_soup.prettify())

# %%
stock_symbol = stock_soup.find("td", class_= "symbol text-left").text
print(stock_symbol)
# Out:
#          AMD

# %%
stock_name = stock_soup.find("td", class_= "symbolName text-left").text
print(stock_name)
# Out:
#        Adv Micro Devices

# %%
stock_price = stock_soup.find("td", class_= "lastPrice").text
print(stock_price)
# Out:
#        46.18

# %%
stock_volume = stock_soup.find("td", class_= "volume").text
print(stock_volume)
# Out:
#        36,624,199

# %%
stock_change = stock_soup.find("td", class_= "percentChange down").text
print(stock_change)
# Out:
#        -0.97%

# %%
stock_symbol_all = stock_soup.find_all("td", class_= "symbol text-left")
stock_name_all = stock_soup.find_all("td", class_= "symbolName text-left")
stock_price_all = stock_soup.find_all("td", class_= "lastPrice")
stock_volume_all = stock_soup.find_all("td", class_= "volume")
stock_change_all = stock_soup.find_all("td", class_= "priceChange down")


# print(stock_symbol_all)

# print(stock_name_all)

# print(stock_price_all)

# print(stock_volume_all)

# print(stock_change_all)

# %%
symbol =[]
for stock in stock_symbol_all:
    #print(stock.text)
    symbol_list = symbol.append(stock.text)
    #print(symbol)

# %%
price =[]
for stock in stock_price_all:
    #print(stock.text)
    price_list = price.append(stock.text)
    #print(price)

# %%
volume = []   
for vol in stock_volume_all:
    #print(vol.text)
    volume_list = volume.append(vol.text)
    #print(volume)

# %%
name = []   
for names in stock_name_all:
    #print(names.text)
    names_list = name.append(names.text)
    #print(name)

# %%
change = []   
for names in stock_change_all:
    #print(names.text)
    change_list = change.append(names.text)
    #print(change)

# %%
# Convert to Pandas dataframe and export in csv
df = pd.DataFrame({'stock_name':name, 'stock_symbol':symbol,'stock_price':price, 'stock_volume':volume}) 
df
# Out:
#                                           stock_name         stock_symbol  \
# 0                            Adv Micro Devices                   AMD
# 1                                    Apple Inc                  AAPL
# 2                     General Electric Company                    GE
# 3                           Ford Motor Company                     F
# 4                         Bank of America Corp                   BAC
# 5                        Uber Technologies Inc                  UBER
# 6                               Microsoft Corp                  MSFT
# 7                                    Vale S.A.                  VALE
# 8                            Micron Technology                    MU
# 9                                     AT&T Inc                     T
# 10                                    Snap Inc                  SNAP
# 11                                  Intel Corp                  INTC
# 12                          Energy Transfer LP                    ET
# 13                                    Roku Inc                  ROKU
# 14                       Luckin Coffee Inc ADR                    LK
# 15                  Caesars Entertainment Corp                   CZR
# 16                              Comcast Corp A                 CMCSA
# 17                        Freeport-Mcmoran Inc                   FCX
# 18                       Alibaba Group Holding                  BABA
# 19                           Cisco Systems Inc                  CSCO
# 20                               Citigroup Inc                     C
# 21                            Exxon Mobil Corp                   XOM
# 22                                 Twitter Inc                  TWTR
# 23                                Facebook Inc                    FB
# 24                                  Macy's Inc                     M
# 25                        Liberty Global Ord C                 LBTYK
# 26          Petroleo Brasileiro S.A. Petrobras                   PBR
# 27                                   Tesla Inc                  TSLA
# 28                       Wells Fargo & Company                   WFC
# 29                                  Pfizer Inc                   PFE
# ..                                               ...                  ...
# 71                                  Abbvie Inc                  ABBV
# 72                     Zayo Group Holdings Inc                  ZAYO
# 73                     The Charles Schwab Corp                  SCHW
# 74                           Pinduoduo Inc ADR                   PDD
# 75                     Marathon Petroleum Corp                   MPC
# 76                                U.S. Bancorp                   USB
# 77                    Walgreens Boots Alliance                   WBA
# 78                             Merck & Company                   MRK
# 79                             Wal-Mart Stores                   WMT
# 80                                    CVS Corp                   CVS
# 81                         Delta Air Lines Inc                   DAL
# 82                    Crowdstrike Holdings Inc                  CRWD
# 83                                 Exelon Corp                   EXC
# 84                           Johnson & Johnson                   JNJ
# 85                          Salesforce.com Inc                   CRM
# 86                             Paypal Holdings                  PYPL
# 87                         Activision Blizzard                  ATVI
# 88                  Southwest Airlines Company                   LUV
# 89                           Applied Materials                  AMAT
# 90                                 Lennar Corp                   LEN
# 91                      Truist Financial Corp.                   TFC
# 92                          Western Digital Cp                   WDC
# 93                                  Home Depot                    HD
# 94                             Las Vegas Sands                   LVS
# 95                   Colgate-Palmolive Company                    CL
# 96                               TJX Companies                   TJX
# 97          Taiwan Semiconductor Manufacturing                   TSM
# 98                      Du Pont De.Nemours Inc                    DD
# 99                     Berkshire Hathaway Cl B                 BRK.B
# 100                                           Name               Symbol
#
#              stock_price             stock_volume
# 0            46.18               36,624,199
# 1           289.80               36,592,902
# 2            11.18               30,009,799
# 3             9.36               28,273,600
# 4            35.35               28,121,000
# 5            30.17               18,465,900
# 6           158.96               18,414,301
# 7            13.22               18,324,199
# 8            54.03               17,188,600
# 9            39.24               15,433,999
# 10           16.03               15,000,000
# 11           60.08               14,086,101
# 12           12.99               13,618,801
# 13          139.52               13,326,900
# 14           36.44               12,743,101
# 15           13.61               12,640,800
# 16           45.10               12,272,500
# 17           13.03               12,066,300
# 18          215.47               11,678,600
# 19           47.77               11,058,900
# 20           79.67               10,867,801
# 21           69.89               10,518,500
# 22           32.55               10,412,899
# 23          208.10               10,287,600
# 24           16.51               10,271,200
# 25           21.84               10,114,700
# 26           15.92               10,012,400
# 27          430.38                9,956,800
# 28           53.92                9,892,700
# 29           39.32                9,599,801
# ..                   ...                      ...
# 71           89.20                4,087,800
# 72           34.59                3,994,400
# 73           48.34                3,733,500
# 74           39.24                3,687,100
# 75           60.38                3,682,800
# 76           59.73                3,661,800
# 77           59.02                3,647,800
# 78           91.50                3,586,700
# 79          119.59                3,545,800
# 80           74.40                3,543,400
# 81           59.08                3,538,700
# 82           48.92                3,510,600
# 83           45.41                3,493,500
# 84          145.75                3,432,600
# 85          164.98                3,410,000
# 86          109.40                3,390,300
# 87           59.19                3,386,400
# 88           54.32                3,348,200
# 89           61.17                3,315,300
# 90           56.00                3,243,100
# 91           56.48                3,232,800
# 92           62.13                3,179,000
# 93          219.97                3,082,800
# 94           69.74                3,002,300
# 95           69.18                2,943,700
# 96           60.85                2,943,700
# 97           58.46                2,847,900
# 98           63.73                2,833,900
# 99          226.14                2,769,600
# 100               Last                   Volume
#
# [101 rows x 4 columns]

# %%
df.to_csv('stocks_large_cap.csv', index=False, encoding='utf-8')
