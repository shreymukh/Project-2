# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup
import requests
import urllib.parse
import pymongo
import pprint
import pandas as pd

# %%
url = 'https://www.barchart.com/stocks/most-active/price-volume-leaders?screener=mid_cap&viewName=main&orderBy=volume&orderDir=desc'
response = requests.get(url)
print(response.status_code)
# Out:
# 403

# %%
# searchterm = urllib.parse.quote('left bold plusIconTd elp')
# print(searchterm)

# %%
# SCRAPING 
# Set the executable path and initialize the chrome browser in splinter
executable_path = {"executable_path":"chromedriver.exe"}
browser = Browser("chrome", **executable_path, headless=False)
browser.visit("https://www.barchart.com/stocks/most-active/price-volume-leaders?screener=mid_cap&viewName=main&orderBy=volume&orderDir=desc")

# %%
# Convert the browser html to a soup object 
soup = browser.html
stock_soup = BeautifulSoup(soup, 'html.parser')

# %%
#print(stock_soup.prettify())

# %%
stock_symbol = stock_soup.find("td", class_= "symbol text-left").text
print(stock_symbol)
# Out:
#          RAD

# %%
stock_name = stock_soup.find("td", class_= "symbolName text-left").text
print(stock_name)
# Out:
#        Rite Aid Corp

# %%
stock_price = stock_soup.find("td", class_= "lastPrice").text
print(stock_price)
# Out:
#        20.30

# %%
stock_volume = stock_soup.find("td", class_= "volume").text
print(stock_volume)
# Out:
#        48,617,297

# %%
stock_change = stock_soup.find("td", class_= "percentChange up").text
print(stock_change)
# Out:
#        +5.78%

# %%
stock_symbol_all = stock_soup.find_all("td", class_= "symbol text-left")
stock_name_all = stock_soup.find_all("td", class_= "symbolName text-left")
stock_price_all = stock_soup.find_all("td", class_= "lastPrice")
stock_volume_all = stock_soup.find_all("td", class_= "volume")
stock_change_all = stock_soup.find_all("td", class_= "percentChange up")


# print(stock_symbol_all)

# print(stock_name_all)

# print(stock_price_all)

# print(stock_volume_all)

# print(stock_change_all)

# %%
symbol =[]
for stock in stock_symbol_all:
    #print(stock.text)
    symbol_list = symbol.append(stock.text)
    #print(symbol)

# %%
price =[]
for stock in stock_price_all:
    #print(stock.text)
    price_list = price.append(stock.text)
    #print(price)

# %%
volume = []   
for vol in stock_volume_all:
    #print(vol.text)
    volume_list = volume.append(vol.text)
    #print(volume)

# %%
name = []   
for names in stock_name_all:
    #print(names.text)
    names_list = name.append(names.text)
    #print(name)

# %%
change = []   
for names in stock_change_all:
    #print(names.text)
    change_list = change.append(names.text)
    #print(change)

# %%
# Convert to Pandas dataframe and export in csv
df = pd.DataFrame({'stock_name':name, 'stock_symbol':symbol,'stock_price':price, 'stock_volume':volume}) 
df
# Out:
#                                             stock_name         stock_symbol  \
# 0                                  Rite Aid Corp                   RAD
# 1                                        Nio Inc                   NIO
# 2                            Oasis Petroleum Inc                   OAS
# 3                       United States Steel Corp                     X
# 4                    Southwestern Energy Company                   SWN
# 5                       Callon Petroleum Company                   CPE
# 6                                 Transocean Inc                   RIG
# 7                                    Yamana Gold                   AUY
# 8                          Envista Holdings Corp                  NVST
# 9                          Antero Midstream Corp                    AM
# 10                          Hecla Mining Company                    HL
# 11                          Range Resources Corp                   RRC
# 12                                   B2Gold Corp                   BTG
# 13                           Qurate Retail Group                 QRTEA
# 14                                Endo Int'l Plc                  ENDP
# 15                              Coeur Mining Inc                   CDE
# 16                          Cleveland-Cliffs Inc                   CLF
# 17                                  Cloudera Inc                  CLDR
# 18                         First Majestic Silver                    AG
# 19                                    Fitbit Inc                   FIT
# 20                                Blackberry Ltd                    BB
# 21                                      Huya Inc                  HUYA
# 22                             MFA Financial Inc                   MFA
# 23                             Farfetch Ltd Cl A                  FTCH
# 24                           Intra-Cellular Ther                  ITCI
# 25                          Ypf Sociedad Anonima                   YPF
# 26                          Pivotal Software Inc                  PVTL
# 27                             Bed Bath & Beyond                  BBBY
# 28                                      Eqt Corp                   EQT
# 29                                Momenta Pharma                  MNTA
# ..                                                 ...                  ...
# 71                                    Fluor Corp                   FLR
# 72                              Macerich Company                   MAC
# 73                     Hertz Global Holdings Inc                   HTZ
# 74                                    Fastly Inc                  FSLY
# 75          Canada Goose Holdings Inc Subordinate V...            GOOS
# 76                               Tripadvisor Inc                  TRIP
# 77                Evoqua Water Technologies Corp                  AQUA
# 78          Essential Properties Realty Trust Inc  ...            EPRT
# 79                                    Inmode Ltd                  INMD
# 80                             Agree Realty Corp                   ADC
# 81                             Yeti Holdings Inc                  YETI
# 82                                     Olin Corp                   OLN
# 83                       Chimera Investment Corp                   CIM
# 84                              Chemours Company                    CC
# 85                           Signet Jewelers Ltd                   SIG
# 86                         Cinemark Holdings Inc                   CNK
# 87                              Lattice Semicond                  LSCC
# 88                              Dcp Midstream LP                   DCP
# 89                               Murphy Oil Corp                   MUR
# 90                            B&G Foods Holdings                   BGS
# 91              Bj's Wholesale Club Holdings Inc                    BJ
# 92                                Stitch Fix Inc                  SFIX
# 93                     Taylor Morrison Home Corp                  TMHC
# 94                        Louisiana-Pacific Corp                   LPX
# 95                           Nektar Therapeutics                  NKTR
# 96                           Wesco International                   WCC
# 97                                  Axsome Thera                  AXSM
# 98                                   Epizyme Inc                  EPZM
# 99                            Livongo Health Inc                  LVGO
# 100                                             Name               Symbol
#
#              stock_price             stock_volume
# 0            20.30               48,617,297
# 1             2.42               37,703,699
# 2             3.12               15,636,100
# 3            11.14               14,570,900
# 4             2.27               13,693,899
# 5             4.71               12,315,101
# 6             6.57               12,132,400
# 7             3.85               10,820,199
# 8            30.01               10,052,800
# 9             7.39                9,037,000
# 10            3.31                8,940,199
# 11            4.56                8,739,300
# 12            3.89                7,119,300
# 13            8.56                6,691,400
# 14            4.45                6,479,600
# 15            7.97                6,007,200
# 16            8.22                5,887,800
# 17           11.77                5,573,000
# 18           11.89                5,446,900
# 19            6.48                5,371,200
# 20            6.45                5,256,200
# 21           18.02                4,698,700
# 22            7.72                4,257,200
# 23           10.32                4,252,900
# 24           35.22                4,033,000
# 25           11.82                3,983,600
# 26           15.00                3,763,000
# 27           17.08                3,676,200
# 28           10.45                3,631,900
# 29           20.36                3,527,000
# ..                   ...                      ...
# 71           18.13                1,557,400
# 72           26.50                1,544,900
# 73           15.66                1,542,800
# 74           20.57                1,460,900
# 75           37.56                1,449,600
# 76           30.29                1,440,700
# 77           18.86                1,423,200
# 78           24.56                1,400,600
# 79           39.02                1,397,900
# 80           69.72                1,396,200
# 81           34.98                1,393,000
# 82           17.23                1,376,100
# 83           21.37                1,368,600
# 84           17.62                1,348,900
# 85           20.99                1,344,600
# 86           33.99                1,323,100
# 87           19.23                1,298,400
# 88           25.03                1,290,200
# 89           26.52                1,283,300
# 90           18.22                1,280,900
# 91           22.76                1,217,500
# 92           25.42                1,214,000
# 93           21.98                1,192,500
# 94           29.93                1,161,500
# 95           21.57                1,155,400
# 96           59.31                1,144,900
# 97          101.98                1,136,900
# 98           22.62                1,089,400
# 99           24.24                1,088,600
# 100               Last                   Volume
#
# [101 rows x 4 columns]

# %%
df.to_csv('stocks_mid_cap.csv', index=False, encoding='utf-8')
