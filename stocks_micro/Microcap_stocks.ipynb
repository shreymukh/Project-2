# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup
import requests
import urllib.parse
import pymongo
import pprint
import pandas as pd

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.stocks
collection = db.micro_cap

# %%
url = 'https://www.barchart.com/stocks/most-active/price-volume-leaders?screener=micro_cap'
response = requests.get(url)
print(response.status_code)
# Out:
# 403

# %%
# searchterm = urllib.parse.quote('left bold plusIconTd elp')
# print(searchterm)

# %%
# SCRAPING 
# Set the executable path and initialize the chrome browser in splinter
executable_path = {"executable_path":"chromedriver.exe"}
browser = Browser("chrome", **executable_path, headless=False)
browser.visit("https://www.barchart.com/stocks/most-active/price-volume-leaders?screener=micro_cap")

# %%
# Convert the browser html to a soup object 
soup = browser.html
stock_soup = BeautifulSoup(soup, 'html.parser')

# %%
#print(stock_soup.prettify())

# %%
stock_symbol = stock_soup.find("td", class_= "symbol text-left").text
print(stock_symbol)
# Out:
#          AZM.VN

# %%
stock_name = stock_soup.find("td", class_= "symbolName text-left").text
print(stock_name)
# Out:
#        Azimut Exploration Inc

# %%
stock_price = stock_soup.find("td", class_= "lastPrice").text
print(stock_price)
# Out:
#        1.500

# %%
stock_volume = stock_soup.find("td", class_= "volume").text
print(stock_volume)
# Out:
#        5,106,903

# %%
stock_change = stock_soup.find("td", class_= "percentChange up").text
print(stock_change)
# Out:
#        +200.00%

# %%
stock_symbol_all = stock_soup.find_all("td", class_= "symbol text-left")
stock_name_all = stock_soup.find_all("td", class_= "symbolName text-left")
stock_price_all = stock_soup.find_all("td", class_= "lastPrice")
stock_volume_all = stock_soup.find_all("td", class_= "volume")
stock_change_all = stock_soup.find_all("td", class_= "percentChange up")


# print(stock_symbol_all)

# print(stock_name_all)

# print(stock_price_all)

# print(stock_volume_all)

# print(stock_change_all)

# %%
symbol =[]
for stock in stock_symbol_all:
    #print(stock.text)
    symbol_list = symbol.append(stock.text)
    #print(symbol)

# %%
price =[]
for stock in stock_price_all:
    #print(stock.text)
    price_list = price.append(stock.text)
    #print(price)

# %%
volume = []   
for vol in stock_volume_all:
    #print(vol.text)
    volume_list = volume.append(vol.text)
    #print(volume)

# %%
name = []   
for names in stock_name_all:
    #print(names.text)
    names_list = name.append(names.text)
    #print(name)

# %%
change = []   
for names in stock_change_all:
    #print(names.text)
    change_list = change.append(names.text)
    #print(change)

# %%
# Convert to Pandas dataframe and export in csv
df = pd.DataFrame({'stock_name':name, 'stock_symbol':symbol,'stock_price':price, 'stock_volume':volume}) 
df
# Out:
#                                             stock_name  \
# 0                         Azimut Exploration Inc
# 1                                   GT Gold Corp
# 2                              Acasti Pharma Inc
# 3                           Xebec Adsorption Inc
# 4                         Questor Technology Inc
# 5                        Lion One Metals Limited
# 6                                Terrascend Corp
# 7                     Chemesis International Inc
# 8                          Exro Technologies Inc
# 9                      Khiron Life Sciences Corp
# 10                      Compass Gold Corporation
# 11              Reconnaissance Energy Africa Ltd
# 12                           American Aires Inc.
# 13                      Skeena Resources Limited
# 14                             Minera Alamos Inc
# 15          Medmen Enterprises Inc Class B Subordin...
# 16                           Green Growth Brands
# 17                       Antibe Therapeutics Inc
# 18           Bee Vectoring Technologies Intl Inc
# 19                                    Weedmd Inc
# 20                                 Core Gold Inc
# 21                                 Kneat.com Inc
# 22                   Galaxy Digital Holdings Ltd
# 23                       Transcanna Holdings Inc
# 24                     Isracann Biosciences Inc.
# 25                              NEO Lithium Corp
# 26                   Liberty Health Sciences Inc
# 27                    Drone Delivery Canada Corp
# 28                         Aurania Resources Ltd
# 29           Vireo Health International Inc S.V.
# ..                                                 ...
# 71                Mineral Mountain Resources Ltd
# 72                         American Lithium Corp
# 73                        Redishred Capital Corp
# 74                      Xphyto Therapeutics Corp
# 75                     Protech Home Medical Corp
# 76                         Poet Technologies Inc
# 77                      Premier Health Group Inc
# 78                  Cantex Mine Development Corp
# 79                                   Frankly Inc
# 80                              Lumina Gold Corp
# 81                          Quantum Numbers Corp
# 82                           Kraken Robotics Inc
# 83                         Lexagene Holdings Inc
# 84                      Radient Technologies Inc
# 85                          Standard Lithium Ltd
# 86                               Btu Metals Corp
# 87                         Discovery Metals Corp
# 88                     Leucrotta Exploration Inc
# 89                      Garibaldi Resources Corp
# 90                             Conic Metals Corp
# 91                       Mustgrow Biologics Corp
# 92                             Prime Mining Corp
# 93                      Greenlane Renewables Inc
# 94                  Rjk Explorations Ltd Cl.A Sv
# 95                               White Gold Corp
# 96                       Captiva Verde Land Corp
# 97                                 Orca Gold Inc
# 98                               Fiore Gold Ltd.
# 99                           Falco Resources Ltd
# 100                                             Name
#
#                stock_symbol         stock_price            stock_volume
# 0               AZM.VN              1.500               5,106,903
# 1               GTT.VN              1.120               1,938,324
# 2              ACST.VN              1.210               1,505,898
# 3               XBC.VN              2.450                 313,597
# 4               QST.VN              5.100                 148,770
# 5               LIO.VN              1.390                 483,950
# 6               TER.CN              3.020                 202,778
# 7               CSI.CN              1.120                 474,425
# 8               XRO.CN              0.570                 923,750
# 9              KHRN.VN              1.030                 502,791
# 10              CVB.VN              0.325               1,493,246
# 11             RECO.VN              0.730                 650,880
# 12             WIFI.CN              0.590                 795,609
# 13              SKE.VN              0.870                 520,476
# 14              MAI.VN              0.260               1,692,072
# 15             MMEN.CN              0.690                 626,613
# 16              GGB.CN              0.650                 650,802
# 17              ATE.VN              0.510                 806,880
# 18              BEE.VN              0.650                 630,864
# 19              WMD.VN              0.780                 474,330
# 20             CGLD.VN              0.265               1,303,010
# 21              KSI.VN              2.790                 118,521
# 22             GLXY.VN              1.320                 235,089
# 23             TCAN.CN              1.640                 183,278
# 24             IPOT.CN              0.395                 728,123
# 25              NLC.VN              0.690                 393,835
# 26              LHS.CN              0.620                 406,597
# 27              FLT.VN              0.900                 270,268
# 28              ARU.VN              3.930                  61,648
# 29             VREO.CN              1.490                 158,083
# ..                      ...                 ...                     ...
# 71              MMV.VN              0.355                 289,858
# 72               LI.VN              0.265                 387,595
# 73              KUT.VN              0.780                 131,670
# 74             XPHY.CN              1.030                  99,151
# 75              PTQ.VN              0.910                 108,680
# 76              PTK.VN              0.370                 262,650
# 77             PHGI.CN              0.465                 193,216
# 78               CD.VN              0.750                 119,452
# 79              TLK.VN              0.710                 125,607
# 80              LUM.VN              0.650                 135,707
# 81              QNC.VN              0.270                 325,889
# 82              PNG.VN              0.610                 144,164
# 83              LXG.VN              0.670                 130,183
# 84              RTI.VN              0.360                 241,224
# 85              SLL.VN              0.890                  96,823
# 86              BTU.VN              0.360                 237,800
# 87              DSV.VN              0.550                 150,528
# 88              LXE.VN              0.780                 103,250
# 89              GGI.VN              0.810                  98,229
# 90              NKL.VN              0.410                 191,061
# 91             MGRO.CN              0.400                 191,750
# 92             PRYM.VN              0.365                 189,100
# 93              GRN.VN              0.415                 161,000
# 94            RJX-A.VN              0.265                 242,672
# 95              WGO.VN              1.030                  60,875
# 96              PWR.CN              0.350                 178,313
# 97              ORG.VN              0.330                 187,250
# 98                F.VN              0.540                 110,151
# 99              FPC.VN              0.315                 184,140
# 100                Symbol                Last                  Volume
#
# [101 rows x 4 columns]

# %%
# Importing the dataframe into mongodb

data = df.to_dict(orient='records')  # Here's our added param..

collection.insert_many(data)

# %%
df.to_csv('stocks_mid_cap.csv', index=False, encoding='utf-8')
