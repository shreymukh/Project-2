# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup
import requests
import urllib.parse
import pymongo
import pprint
import pandas as pd

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.stocks
collection = db.micro_cap

# %%
url = 'https://www.barchart.com/stocks/most-active/price-volume-leaders?screener=micro_cap'
response = requests.get(url)
print(response.status_code)
# Out:
# 403

# %%
# searchterm = urllib.parse.quote('left bold plusIconTd elp')
# print(searchterm)

# %%
# SCRAPING 
# Set the executable path and initialize the chrome browser in splinter
executable_path = {"executable_path":"chromedriver.exe"}
browser = Browser("chrome", **executable_path, headless=False)
browser.visit("https://www.barchart.com/stocks/most-active/price-volume-leaders?screener=micro_cap")

# %%
# Convert the browser html to a soup object 
soup = browser.html
stock_soup = BeautifulSoup(soup, 'html.parser')

# %%
#print(stock_soup.prettify())

# %%
stock_symbol = stock_soup.find("td", class_= "symbol text-left").text
print(stock_symbol)
# Out:
#          ONC.TO

# %%
stock_name = stock_soup.find("td", class_= "symbolName text-left").text
print(stock_name)
# Out:
#        Oncolytics Bio

# %%
stock_price = stock_soup.find("td", class_= "lastPrice").text
print(stock_price)
# Out:
#        5.51

# %%
stock_volume = stock_soup.find("td", class_= "volume").text
print(stock_volume)
# Out:
#        1,634,059

# %%
stock_change = stock_soup.find("td", class_= "percentChange up").text
print(stock_change)
# Out:
#        +14.79%

# %%
stock_symbol_all = stock_soup.find_all("td", class_= "symbol text-left")
stock_name_all = stock_soup.find_all("td", class_= "symbolName text-left")
stock_price_all = stock_soup.find_all("td", class_= "lastPrice")
stock_volume_all = stock_soup.find_all("td", class_= "volume")
stock_change_all = stock_soup.find_all("td", class_= "percentChange up")


# print(stock_symbol_all)

# print(stock_name_all)

# print(stock_price_all)

# print(stock_volume_all)

# print(stock_change_all)

# %%
symbol =[]
for stock in stock_symbol_all:
    #print(stock.text)
    symbol_list = symbol.append(stock.text)
    #print(symbol)

# %%
price =[]
for stock in stock_price_all:
    #print(stock.text)
    price_list = price.append(stock.text)
    #print(price)

# %%
volume = []   
for vol in stock_volume_all:
    #print(vol.text)
    volume_list = volume.append(vol.text)
    #print(volume)

# %%
name = []   
for names in stock_name_all:
    #print(names.text)
    names_list = name.append(names.text)
    #print(name)

# %%
change = []   
for names in stock_change_all:
    #print(names.text)
    change_list = change.append(names.text)
    #print(change)

# %%
# Convert to Pandas dataframe and export in csv
df = pd.DataFrame({'stock_name':name, 'stock_symbol':symbol,'stock_price':price, 'stock_volume':volume}) 
df
# Out:
#                                             stock_name           stock_symbol  \
# 0                                 Oncolytics Bio                  ONC.TO
# 1                           Xebec Adsorption Inc                  XBC.VN
# 2                        Transcanna Holdings Inc                 TCAN.CN
# 3                  Well Health Technologies Corp                 WELL.VN
# 4                      Generation Mining Limited                 GENM.CN
# 5                        Medical Facilities Corp                   DR.TO
# 6                           Bonterra Energy Corp                  BNE.TO
# 7                      Namaste Technologies Inc.                    N.VN
# 8                       Pizza Pizza Royalty Corp                  PZA.TO
# 9                      Isracann Biosciences Inc.                 IPOT.CN
# 10                  Cantex Mine Development Corp                   CD.VN
# 11                         The Yield Growth Corp                 BOSS.CN
# 12                         Exro Technologies Inc                  XRO.CN
# 13                       Lion One Metals Limited                  LIO.VN
# 14            Dividend Growth Split Corp Class A                  DGS.TO
# 15                                 Kneat.com Inc                  KSI.VN
# 16          Medmen Enterprises Inc Class B Subordin...           MMEN.CN
# 17                        Integra Resources Corp                  ITR.VN
# 18                       Flower One Holdings Inc                 FONE.CN
# 19                  Eco Atlantic Oil and Gas Ltd                  EOG.VN
# 20                       Baylin Technologies Inc                  BYL.TO
# 21                        Bonterra Resources Inc                  BTR.VN
# 22                              Ecosynthetix Inc                  ECO.TO
# 23                Enthusiast Gaming Holdings Inc                 EGLX.VN
# 24                           Aurcana Corporation                  AUN.VN
# 25                       Canada Cobalt Works Inc                  CCW.VN
# 26                   Liberty Health Sciences Inc                  LHS.CN
# 27                   Medicenna Therapeutics Corp                 MDNA.TO
# 28                          Benchmark Metals Inc                 BNCH.VN
# 29                     Khiron Life Sciences Corp                 KHRN.VN
# ..                                                 ...                    ...
# 71                          Standard Lithium Ltd                  SLL.VN
# 72                           Green Growth Brands                  GGB.CN
# 73                Critical Elements Lithium Corp                  CRE.VN
# 74                             Gfg Resources Inc                  GFG.VN
# 75                             Tilt Holdings Inc                 TILT.CN
# 76               Emerald Health Therapeutics Inc                  EMH.VN
# 77                          Osino Resources Corp                  OSI.VN
# 78                      Silver One Resources Inc                  SVE.VN
# 79                            Impact Silver Corp                  IPT.VN
# 80                           Falco Resources Ltd                  FPC.VN
# 81                     Cannabix Technologies Inc                  BLO.CN
# 82                        Westhaven Ventures Inc                  WHN.VN
# 83                        Ely Gold Royalties Inc                  ELY.VN
# 84                         Vizsla Resources Corp                 VZLA.VN
# 85                         48North Cannabis Corp                 NRTH.VN
# 86                      Compass Gold Corporation                  CVB.VN
# 87                   Speakeasy Cannabis Club Ltd                 EASY.CN
# 88                              Lumina Gold Corp                  LUM.VN
# 89                      Greenlane Renewables Inc                  GRN.VN
# 90                                Petroshale Inc                  PSH.VN
# 91                      Nexoptic Technology Corp                  NXO.VN
# 92                     Ynvisible Interactive Inc                  YNV.VN
# 93                         Poet Technologies Inc                  PTK.VN
# 94                          Strategic Metals Ltd                  SMD.VN
# 95                         Empire Industries Ltd                  EIL.VN
# 96                               White Gold Corp                  WGO.VN
# 97                           Sirona Biochem Corp                  SBM.VN
# 98                               Btu Metals Corp                  BTU.VN
# 99                              NEO Lithium Corp                  NLC.VN
# 100                                             Name                 Symbol
#
#             stock_price            stock_volume
# 0            5.51               1,634,059
# 1           2.550                 847,360
# 2           1.600               1,329,865
# 3           1.660               1,049,699
# 4           0.380               3,393,729
# 5            4.55                 223,286
# 6            4.47                 193,953
# 7           0.355               2,123,140
# 8            9.86                  66,009
# 9           0.510               1,268,716
# 10          0.840                 765,928
# 11          0.255               2,406,870
# 12          0.495               1,174,536
# 13          1.750                 325,545
# 14           5.20                 101,046
# 15          3.010                 165,575
# 16          0.670                 629,114
# 17          1.200                 350,291
# 18          0.870                 469,619
# 19          1.100                 330,124
# 20           2.42                 148,805
# 21          2.040                 167,995
# 22           2.63                 129,785
# 23          1.850                 180,936
# 24          0.310               1,050,899
# 25          0.710                 458,221
# 26          0.570                 545,432
# 27           3.05                  99,587
# 28          0.415                 722,245
# 29          0.990                 302,680
# ..                  ...                     ...
# 71          0.830                 156,543
# 72          0.750                 172,929
# 73          0.360                 356,404
# 74          0.350                 363,277
# 75          0.375                 336,380
# 76          0.305                 410,994
# 77          0.700                 176,222
# 78          0.380                 319,844
# 79          0.430                 280,768
# 80          0.295                 408,313
# 81          0.520                 228,382
# 82          0.970                 113,672
# 83          0.440                 248,529
# 84          0.720                 146,474
# 85          0.350                 299,188
# 86          0.580                 175,400
# 87          0.380                 262,908
# 88          0.650                 142,111
# 89          0.440                 209,602
# 90          0.590                 154,375
# 91          0.390                 221,965
# 92          0.290                 292,727
# 93          0.380                 222,674
# 94          0.490                 165,000
# 95          0.470                 166,100
# 96          1.100                  69,452
# 97          0.455                 166,426
# 98          0.320                 235,851
# 99          0.520                 138,294
# 100              Last                  Volume
#
# [101 rows x 4 columns]

# %%
# Importing the dataframe into mongodb

data = df.to_dict(orient='records')  # Here's our added param..

collection.insert_many(data)

# %%
df.to_csv('stocks_mid_cap.csv', index=False, encoding='utf-8')
