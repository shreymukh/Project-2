# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup
import requests
import urllib.parse
import pymongo
import pprint
import pandas as pd

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.stocks
collection = db.mid_cap

# %%
url = 'https://www.barchart.com/stocks/most-active/price-volume-leaders?screener=mid_cap'
response = requests.get(url)
print(response.status_code)
# Out:
# 403

# %%
# searchterm = urllib.parse.quote('left bold plusIconTd elp')
# print(searchterm)

# %%
# SCRAPING 
# Set the executable path and initialize the chrome browser in splinter
executable_path = {"executable_path":"chromedriver.exe"}
browser = Browser("chrome", **executable_path, headless=False)
browser.visit("https://www.barchart.com/stocks/most-active/price-volume-leaders?screener=mid_cap")

# %%
# Convert the browser html to a soup object 
soup = browser.html
stock_soup = BeautifulSoup(soup, 'html.parser')

# %%
#print(stock_soup.prettify())

# %%
stock_symbol = stock_soup.find("td", class_= "symbol text-left").text
print(stock_symbol)
# Out:
#          SDC

# %%
stock_name = stock_soup.find("td", class_= "symbolName text-left").text
print(stock_name)
# Out:
#        Smiledirectclub Inc

# %%
stock_price = stock_soup.find("td", class_= "lastPrice").text
print(stock_price)
# Out:
#        10.19

# %%
stock_volume = stock_soup.find("td", class_= "volume").text
print(stock_volume)
# Out:
#        39,109,736

# %%
stock_change = stock_soup.find("td", class_= "percentChange up").text
print(stock_change)
# Out:
#        +21.60%

# %%
stock_symbol_all = stock_soup.find_all("td", class_= "symbol text-left")
stock_name_all = stock_soup.find_all("td", class_= "symbolName text-left")
stock_price_all = stock_soup.find_all("td", class_= "lastPrice")
stock_volume_all = stock_soup.find_all("td", class_= "volume")
stock_change_all = stock_soup.find_all("td", class_= "percentChange up")


# print(stock_symbol_all)

# print(stock_name_all)

# print(stock_price_all)

# print(stock_volume_all)

# print(stock_change_all)

# %%
symbol =[]
for stock in stock_symbol_all:
    #print(stock.text)
    symbol_list = symbol.append(stock.text)
    #print(symbol)

# %%
price =[]
for stock in stock_price_all:
    #print(stock.text)
    price_list = price.append(stock.text)
    #print(price)

# %%
volume = []   
for vol in stock_volume_all:
    #print(vol.text)
    volume_list = volume.append(vol.text)
    #print(volume)

# %%
name = []   
for names in stock_name_all:
    #print(names.text)
    names_list = name.append(names.text)
    #print(name)

# %%
change = []   
for names in stock_change_all:
    #print(names.text)
    change_list = change.append(names.text)
    #print(change)

# %%
# Convert to Pandas dataframe and export in csv
df = pd.DataFrame({'stock_name':name, 'stock_symbol':symbol,'stock_price':price, 'stock_volume':volume})
df
# Out:
#                                             stock_name        stock_symbol  \
# 0                            Smiledirectclub Inc                  SDC
# 1                                        Nio Inc                  NIO
# 2                  Restoration Hardware Holdings                   RH
# 3                                     Arqule Inc                 ARQL
# 4                      Commercial Metals Company                  CMC
# 5                      Audentes Therapeutics Inc                 BOLD
# 6                          Envista Holdings Corp                 NVST
# 7                                Beyond Meat Inc                 BYND
# 8                                    Grubhub Inc                 GRUB
# 9              Weight Watchers International Inc                   WW
# 10                            Cal-Maine Foods IN                 CALM
# 11                             Cyberark Soft Ord                 CYBR
# 12                            Enphase Energy Inc                 ENPH
# 13                             Bed Bath & Beyond                 BBBY
# 14                                  Axsome Thera                 AXSM
# 15                                Footlocker Inc                   FL
# 16                                      Axon Inc                 AAXN
# 17                             Wright Med Grp NV                 WMGI
# 18                                   Fireeye Inc                 FEYE
# 19                             Yeti Holdings Inc                 YETI
# 20                      United States Steel Corp                    X
# 21                                Transocean Inc                  RIG
# 22                              Coeur Mining Inc                  CDE
# 23                                Solaredge Tech                 SEDG
# 24                                      Huya Inc                 HUYA
# 25                              Eldorado Resorts                  ERI
# 26                             Helmerich & Payne                   HP
# 27                                   Logmein Inc                 LOGM
# 28                                      Eqt Corp                  EQT
# 29                     Intercept Pharmaceuticals                 ICPT
# ..                                                 ...                 ...
# 71                                    Inmode Ltd                 INMD
# 72                               Thor Industries                  THO
# 73                                  Kratos Defns                 KTOS
# 74                                Murphy USA Inc                 MUSA
# 75                                Blackberry Ltd                   BB
# 76            Seaworld Entertainment Inc Company                 SEAS
# 77                         Tenet Healthcare Corp                  THC
# 78                             Delek US Holdings                   DK
# 79                                      SLM Corp                  SLM
# 80                           Texas Capital Bncsh                 TCBI
# 81                          Deckers Outdoor Corp                 DECK
# 82          Biohaven Pharmaceutical Holding Company...           BHVN
# 83                                    Fitbit Inc                  FIT
# 84                         Plains Gp Holdings LP                 PAGP
# 85                            Sanderson Farms IN                 SAFM
# 86                          Ironwood Pharmaceuti                 IRWD
# 87                         Evercore Partners Inc                  EVR
# 88                                      NCR Corp                  NCR
# 89                                  Virtusa Corp                 VRTU
# 90                          Goodyear Tire Rubber                   GT
# 91                                 Insperity Inc                  NSP
# 92                          Coresite Realty Corp                  COR
# 93                                   Ehealth Inc                 EHTH
# 94             Graphic Packaging Holding Company                  GPK
# 95                     Spirit Realty Capital Inc                  SRC
# 96                               Tripadvisor Inc                 TRIP
# 97                                Owens-Illinois                   OI
# 98                        Boot Barn Holdings Inc                 BOOT
# 99                                   Valaris Plc                  VAL
# 100                                             Name              Symbol
#
#              stock_price              stock_volume
# 0            10.19                39,109,736
# 1             3.68               106,377,237
# 2           212.77                 1,463,029
# 3            20.04                15,177,200
# 4            22.12                10,059,530
# 5            60.00                 3,199,375
# 6            30.96                 6,116,686
# 7            74.59                 2,289,976
# 8            49.25                 3,462,214
# 9            39.14                 3,812,520
# 10           39.11                 3,611,158
# 11          126.78                 1,090,253
# 12           29.66                 4,582,587
# 13           16.56                 7,972,291
# 14           94.48                 1,388,017
# 15           38.79                 3,129,973
# 16           68.75                 1,716,043
# 17           30.51                 3,682,918
# 18           17.59                 6,228,727
# 19           32.12                 3,277,356
# 20           10.79                 9,520,677
# 21            7.17                13,895,178
# 22            6.93                13,986,344
# 23           99.63                   968,301
# 24           19.83                 4,815,150
# 25           58.80                 1,610,474
# 26           47.15                 1,998,726
# 27           86.05                 1,025,566
# 28           10.46                 8,246,262
# 29          113.19                   728,342
# ..                   ...                       ...
# 71           35.04                 1,524,761
# 72           70.90                   753,060
# 73           20.20                 2,633,901
# 74          111.97                   469,658
# 75            6.68                 7,832,812
# 76           32.44                 1,600,490
# 77           37.51                 1,380,279
# 78           32.84                 1,574,261
# 79            8.82                 5,853,023
# 80           55.58                   926,581
# 81          174.50                   294,642
# 82           53.74                   955,922
# 83            6.50                 7,843,863
# 84           19.74                 2,575,987
# 85          173.95                   292,186
# 86           14.01                 3,613,444
# 87           73.84                   685,246
# 88           34.70                 1,456,425
# 89           41.56                 1,204,265
# 90           14.95                 3,344,302
# 91           87.84                   568,450
# 92          111.78                   439,605
# 93           99.00                   495,434
# 94           16.09                 3,044,345
# 95           49.28                   985,419
# 96           30.06                 1,614,280
# 97           12.66                 3,819,869
# 98           47.11                 1,026,077
# 99            7.70                 6,204,816
# 100               Last                    Volume
#
# [101 rows x 4 columns]

# %%
# Importing the dataframe into mongodb

data = df.to_dict(orient='records')  # Here's our added param..

collection.insert_many(data)

# %%
df.to_csv('stocks_mid_cap.csv', index=False, encoding='utf-8')
